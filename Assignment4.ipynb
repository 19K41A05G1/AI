# %% [markdown]
# <a href="https://colab.research.google.com/github/19K41A05G1/AI/blob/main/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import xlrd

# %%
book=xlrd.open_workbook(filename='/content/drive/MyDrive/slr09.xls')
df=pd.read_excel(book)
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'

# %%
df.head()
# Out:
#      X    Y
# 0  7.6  157
# 1  7.1  174
# 2  8.2  175
# 3  7.5  188
# 4  7.4  171

# %%
X = df['X'].values
y = df['Y'].values

# %%
X = X.reshape(-1,1)
y = y.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %%
X_train
# Out:
# array([[8.2],
#        [8.4],
#        [6.7],
#        [8.5],
#        [8.1],
#        [7.3],
#        [7.8],
#        [8.1],
#        [8. ],
#        [7.1],
#        [7.8],
#        [7.3],
#        [7.8],
#        [7.3],
#        [8.5],
#        [7.2],
#        [7.1],
#        [7.3],
#        [7.3],
#        [7.9],
#        [7.4],
#        [8.2],
#        [8.8],
#        [7.9],
#        [7.5],
#        [8. ],
#        [7.1],
#        [7.4],
#        [7.5],
#        [7.6]])

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
m = lm.coef_
c = lm.intercept_,
print("Estimated model slope, m:" , m)
print("Estimated model intercept, c:" , c)
# Out:
# Estimated model slope, m: [[-30.97868174]]
# Estimated model intercept, c: (array([377.83911166]),)

# %%
y_pred_train=lm.predict(X_train)
y_pred_test=lm.predict(X_test)

# %%
import math
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error


#Training Accuracies
rmse = math.sqrt(mean_squared_error(y_train, y_pred_train)) 
print('Root mean square error', rmse) 
mse = (mean_squared_error(y_train, y_pred_train)) 
print('Mean square error', mse) 
mae=mean_absolute_error(y_train, y_pred_train)
print('Mean absolute error', mae)
# Out:
# Root mean square error 53.65417854583525
# Mean square error 2878.7708754283676
# Mean absolute error 46.5692850890857

# %%
#Testing Accuracies
rmse = math.sqrt(mean_squared_error(y_test, y_pred_test)) 
print('Root mean square error', rmse) 
mse = (mean_squared_error(y_test, y_pred_test)) 
print('Mean square error', mse) 
mae=mean_absolute_error(y_test, y_pred_test)
print('Mean absolute error', mae)
# Out:
# Root mean square error 35.585382928993646
# Mean square error 1266.3194782031123
# Mean absolute error 32.75583025501805

# %%
import pickle
# Save the model
filename = 'model.pkl'
pickle.dump(lm, open(filename, 'wb'))

# %%
model = pickle.load(open('model.pkl', 'rb'))
user_ip=input('enter x value')
adv=np.array(float(user_ip))
adv=adv.reshape(-1,1)
prediction = model.predict(adv)
result = prediction[0]
print('x',float(user_ip))
print('y',result)
# Out:
# enter x value5
# x 5.0
# y [222.94570297]

# %% [markdown]
# ![WhatsApp Image 2021-11-12 at 9.52.48 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-12 at 9.53.16 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-12 at 9.53.42 PM.jpeg](data:image/jpeg;base64,...)
